# %% [markdown]
# <a href="https://colab.research.google.com/github/villafue/LinkedIn_Python_Stastics_Essential_Training/blob/master/03_05_morevariables_end.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Python statistics essential training - 03_05_morevariables

# %% [markdown]
# Standard imports

# %%
import numpy as np
import scipy.stats
import pandas as pd
import os

# %%
import matplotlib
import matplotlib.pyplot as plt

import pandas.plotting

from IPython import display
from ipywidgets import interact, widgets

# %matplotlib inline

# %%
import re
import mailbox
import csv

# %%
os.chdir('sample_data')

# %%
gapminder = pd.read_csv('gapminder.csv')

# %%
def plotyear(year):
    data = gapminder[gapminder.year == year]
    
    data.plot.scatter('gdp_per_day','life_expectancy',logx=True)

plotyear(1965)

# %%
def plotyear(year):
  data = gapminder[gapminder.year == year].sort_values('population',ascending=False)
  area = 5e-6 * data.population
  color = data.age5_surviving
  data.plot.scatter('gdp_per_day','life_expectancy',logx=True,
                    s=area, c=color,
                    colormap=matplotlib.cm.get_cmap('Purples_r'),
                    linewidths=1, edgecolors='k', vmin=55, vmax=100,
                    sharex=False
                    )
plotyear(1965)

# %%
def plotyear(year):
    data = gapminder[gapminder.year == year].sort_values('population',ascending=False)
    area = 5e-6 * data.population
    color = data.age5_surviving
    
    data.plot.scatter('gdp_per_day','life_expectancy',logx=True,
                      s=area, c=color,
                      colormap=matplotlib.cm.get_cmap('Purples_r'), vmin=55, vmax=100,
                      linewidths=1, edgecolors='k', sharex=False)

plotyear(1965)

# %%
def plotyear(year):
  data = gapminder[gapminder.year == year].sort_values('population',ascending=False)
  area = 5e-6 * data.population
  color = data.age5_surviving
  edgecolor = data.region.map({'Africa': 'skyblue','Europe': 'gold','America': 'palegreen','Asia': 'coral'})
  
  data.plot.scatter('gdp_per_day','life_expectancy',logx=True,
                    s=area, c=color,
                    colormap=matplotlib.cm.get_cmap('Purples_r'),
                    linewidths=1, edgecolors=edgecolor, vmin=55, vmax=100,
                    sharex=False, figsize=(10,6.5))
  
  plt.axis(xmin=1,xmax=50,ymin=30,ymax=100)

plotyear(1965)

# %%
def plotyear(year):
    data = gapminder[gapminder.year == year].sort_values('population',ascending=False)
    area = 5e-6 * data.population
    color = data.age5_surviving
    edgecolor = data.region.map({'Africa': 'skyblue','Europe': 'gold','America': 'palegreen','Asia': 'coral'})
    
    data.plot.scatter('gdp_per_day','life_expectancy',logx=True,
                      s=area, c=color,
                      colormap=matplotlib.cm.get_cmap('Purples_r'), vmin=55, vmax=100,
                      linewidths=1, edgecolors=edgecolor, sharex=False,
                      figsize=(10,6.5))

    pp.axis(xmin=1,xmax=500,ymin=30,ymax=100)
    
plotyear(1965)

# %%
interact(plotyear,year=range(1965,2016,10))
# Out:
# interactive(children=(Dropdown(description='year', options=(1965, 1975, 1985, 1995, 2005, 2015), value=1965), …
# <function __main__.plotyear>

# %%
interact(plotyear,year=range(1965,2016,10))
# Out:
# interactive(children=(Dropdown(description='year', options=(1965, 1975, 1985, 1995, 2005, 2015), value=1965), Output()), _dom_classes=('widget-interact',))
# <function __main__.plotyear>

# %%
gapminder[gapminder.year == 2015].population.sum()
# Out:
# 7292414176.0

# %%
gapminder[gapminder.year == 2015].population.sum()
# Out:
# 7292414176.0

# %%
gapminder[gapminder.year == 2015].groupby('region').population.sum()
# Out:
# region
# Africa     1.172161e+09
# America    9.865771e+08
# Asia       4.299142e+09
# Europe     8.345345e+08
# Name: population, dtype: float64

# %%
gapminder[gapminder.year == 2015].groupby('region').population.sum()
# Out:
# region
# Africa     1.172161e+09
# America    9.865771e+08
# Asia       4.299142e+09
# Europe     8.345345e+08
# Name: population, dtype: float64

# %%
def plotyear(year):
  data = gapminder[gapminder.year == year].sort_values('population',ascending=False)
  area = 5e-6 * data.population
  color = data.age5_surviving
  edgecolor = data.region.map({'Africa': 'skyblue','Europe': 'gold','America': 'palegreen','Asia': 'coral'})
  
  data.plot.scatter('gdp_per_day','life_expectancy',logx=True,
                    s=area, c=color,
                    colormap=matplotlib.cm.get_cmap('Purples_r'),
                    linewidths=1, edgecolors=edgecolor, vmin=55, vmax=100,
                    sharex=False, figsize=(10,6.5))
  
  for level in [4,16,64]:
    pp.axvline(level,linestyle=':',color='k')
  
  plt.axis(xmin=1,xmax=50,ymin=30,ymax=100)

plotyear(2015)

# %%
def plotyear(year):
    data = gapminder[gapminder.year == year].sort_values('population',ascending=False)
    area = 5e-6 * data.population
    color = data.age5_surviving
    edgecolor = data.region.map({'Africa': 'skyblue','Europe': 'gold','America': 'palegreen','Asia': 'coral'})
    
    data.plot.scatter('gdp_per_day','life_expectancy',logx=True,
                      s=area, c=color,
                      colormap=matplotlib.cm.get_cmap('Purples_r'), vmin=55, vmax=100,
                      linewidths=1, edgecolors=edgecolor, sharex=False,
                      figsize=(10,6.5))

    for level in [4,16,64]:
        pp.axvline(level,linestyle=':',color='k')
    
    pp.axis(xmin=1,xmax=500,ymin=30,ymax=100)
    
plotyear(2015)

# %%
data = gapminder.loc[gapminder.year == 2015,['gdp_per_day','life_expectancy','age5_surviving','babies_per_woman']]

pandas.plotting.scatter_matrix(data,figsize=(9,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb680603320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb680691438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb6805585c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb67ec0df98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb680740048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb680ef4550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb680eeee80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb67ed52c88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb67ed52550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb67e5c02b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb67eab34a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb680f38860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb680eb38d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb67e80fb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb67e5b6d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb67ecabfd0>]],
#       dtype=object)

# %%
gapminder['log10_gdp_per_day'] = np.log10(data['gdp_per_day'])
data = gapminder.loc[gapminder.year == 2015,['log10_gdp_per_day','life_expectancy','age5_surviving','babies_per_woman']]


pandas.plotting.scatter_matrix(data,figsize=(9,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb67a13da20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb679df5c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb679da2f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb679d602b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb679d12550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb679d438d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb679cf5c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb679ca8f98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb679cb6048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb679c19710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb679c4aa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb679bfde10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb679bbb1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb679b6e550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb6805de588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb680f56be0>]],
#       dtype=object)

# %%
gapminder['log10_gdp_per_day'] = np.log10(data['gdp_per_day'])
data = gapminder.loc[gapminder.year == 2015,['log10_gdp_per_day','life_expectancy','age5_surviving','babies_per_woman']]


pandas.plotting.scatter_matrix(data,figsize=(9,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a169aae10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a167a9240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a167dd240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a162c32b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a170702b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a170702e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a170cea90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a170ec4a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1713ea20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a170d8cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a171a94e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a171e39b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1721cef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a17244cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1727cf60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a172c4320>]],
#       dtype=object)
